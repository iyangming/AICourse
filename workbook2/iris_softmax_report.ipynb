# %% [markdown]
# # Softmax回归在鸢尾花数据集上的实验报告

# %% [markdown]
# ## 一、实验目的
# 使用Softmax回归模型对鸢尾花数据集进行三分类实验，探索不同特征组合、训练比例以及超参数设置对模型准确率与训练性能的影响。

# %% [markdown]
# ## 二、属性选择策略
# 通过可视化分析，发现花瓣长度与宽度对三类鸢尾花的区分度最高。相比之下，萼片属性的重叠较多，判别能力较弱。因此优先选择花瓣属性，再逐步加入其他属性构建组合。

# %% [markdown]
# ## 三、模型训练与结果可视化
# 1. 使用 petal length 和 petal width 两个特征。
# 2. 建立 Softmax 回归模型（LogisticRegression with multi_class='multinomial'）。
# 3. 结果可视化显示三类鸢尾花的分布与模型决策边界。

# %% [markdown]
# ## 四、超参数调优实验
# 尝试不同学习率和迭代次数对模型性能的影响，包含训练损失、测试损失与训练时间对比图。

# %%
from IPython.display import Image
Image(filename="./loss_vs_iter.png")

# %%
from IPython.display import Image
Image(filename="./train_time_vs_lr.png")

# %% [markdown]
# ## 五、属性组合对比实验
# 实验结果显示：
# - 使用 petal 特征的模型准确率最高
# - 加入 sepal length 后略有提升
# - 使用全部四个特征准确率稳定但无明显提升
#
# 推荐选择 petal length 和 width 作为输入。

# %% [markdown]
# ## 六、训练集比例影响分析
# 在 60%-90% 训练集比例下模型表现稳定，70%-80% 区间准确率最佳。训练集比例过高可能导致过拟合，比例过低可能欠拟合。

# %% [markdown]
# ## 七、实验总结与启发
# 1. 特征选择是模型性能的关键因素。
# 2. Softmax回归在鸢尾花三分类问题中表现良好。
# 3. 超参数调节（学习率、迭代次数、训练比例）显著影响性能。
# 4. 可视化直观展示了模型边界与性能差异，有助于模型分析。
